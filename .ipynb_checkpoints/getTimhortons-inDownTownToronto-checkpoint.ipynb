# %%
import pandas as pd
import time
import json
import datetime
import pprint
from selenium import webdriver
from datetime import datetime
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains

# global str
# string= "Currently 27% busy, usually 33% busy."
import re
getPlaceIDURL='https://googlemaps.github.io/js-samples/dist/samples/places-placeid-finder/index.html'
###############################################
#loading URL_list
df = pd.read_csv ('TimhortonsURL.csv')
# print (df)
print(df.info())
df=df.drop_duplicates(subset = ["URL"])
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   URL     173 non-null    object
# dtypes: object(1)
# memory usage: 1.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 0 to 168
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   URL     68 non-null     object
# dtypes: object(1)
# memory usage: 1.1+ KB
# None

# %%
url_list= df["URL"].values
# print(url_list)
#####################################################################
#opernWebdriver
browser = webdriver.Firefox()
######################################################################
weekDay=["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]
# a Python object (dict):

########################################### prepare document to collect the data
for url in url_list:
    #################################
    document = {}
    document["GoogleID"]="213424325432sdfdg"
    document["currently-occupied-by"]= 112
    document["name"]="Tim Hortons"
    document["address"]="195 Westney Rd S, Ajax, ON L1S 2C9"

    for i in weekDay:
        document[i]={}
    #################################################
    browser.get(url)
    browser.execute_script("window.scrollTo(0, 20)") 
    #############################################################
    #get the addresss
    time.sleep(4)
    data_item_id=browser.find_elements(By.XPATH,"//button[@data-item-id='address']")
     
    for div in  data_item_id:
        if div.get_attribute('aria-label'):
    #             print(div.get_attribute('aria-label'))
                string=div.get_attribute('aria-label')
    #             print(string[string.find(": ")+2:])
                string= string[string.find(": ")+2:-1]+', Canada'  #to fix the extera space at the end
                document["address"]=string
                print(string)
    #############################################################
    div_tag =browser.find_elements(By.TAG_NAME , "div")
   
    weekIndex=-1
    lastTime="p.m"
    for div in  div_tag:
        if div.get_attribute('aria-label'):
            divString=div.get_attribute('aria-label')
            if divString:
                ####################################
                if "a.m" in divString and "p.m" in lastTime:
                    weekIndex=weekIndex+1 ##a new day    
                #################################### case of currently time         
                if "Currently" in divString:
                    busy= re.findall(r'\d+',divString)[1]
                    now = datetime.now()
                    AMorPM=" a.m"
                    current_time = now.strftime("%H")
                    if int(current_time)>12:
                        current_time=int(current_time)%12
                        current_time=str(current_time)
                        AMorPM=" p.m"
                    theTime=current_time+AMorPM
                    document[weekDay[weekIndex]][theTime]=busy
                    lastTime=theTime
                if "a.m" in divString or "p.m" in divString:
#                     busy=int(divString[0:divString.find("%")])
                    busy=int(re.findall(r'\d+',divString)[0])
                    if "a.m" in divString:
                        AMorPM = " a.m"
                    else:
                        AMorPM = " p.m"
                    timepm= re.findall(r'\d+',divString)[1]
                    theTime= timepm+AMorPM
                    document[weekDay[weekIndex]][theTime]=busy
                    lastTime=theTime
#     pprint.pprint(document)

    #############################################
    #get PlaceID using the saved Address
    browser.get(getPlaceIDURL)
    input_text= browser.find_element(By.XPATH,"//input[@id='pac-input']")
    time.sleep(3)
    input_text.click()
    input_text.send_keys('Tim Hortons, '+document["address"])
    time.sleep(1)
    input_text.send_keys(Keys.ARROW_DOWN)
    input_text.send_keys(Keys.ENTER)
    time.sleep(1)

    document["GoogleID"]=browser.find_element(By.XPATH, "//span[@id='place-id']").text
    print(document["GoogleID"])
    #############################################
    df_data =pd.DataFrame([document])
    df_data.to_csv('data.csv', mode='a', index=False, header=False)
# Out:
# 745 College St, Toronto, ON M6G 1C5, Canada
# ChIJr1Ri1fA0K4gR65OFmurbqCU
# 726 Bloor St W, Toronto, ON M6G 4A1, Canada
# ChIJTVHK7Yw0K4gRdbyPtcSATNE
# 1167 Queen St W, Toronto, ON M6J 1J4, Canada
# ChIJkbolmqI1K4gRbdVtkmNI2Hk
# 1094 Bloor St W, Toronto, ON M6H 1M5, Canada
# ChIJj-o4XIs0K4gR3xBjxfYXs_c
# 900 Dufferin St Unit 0565, Toronto, ON M6H 4B1, Canada
# ChIJQ3Ne3Vo0K4gRE5nyCbt2zzE
# 1269 College St, Toronto, ON M6H 1C5, Canada
# ChIJw33iik40K4gRKLOqLx1tkPw
# 720 King St W, Toronto, ON M5V 2T3, Canada
# ChIJOcdLZ-A0K4gRzERBTtvAJLY
# 1033 Queen St W, Toronto, ON M6J 0A6, Canada
# ChIJaWFCIv40K4gRTd1q7EeAm8I
# 750 Dundas St W, Toronto, ON M6J 3S3, Canada
# ChIJEYyn8eg0K4gRF4wEChQ9Y8M
# 874 Bloor St W, Toronto, ON M6G 1M5, Canada
# ChIJLVe5VvU0K4gRLzHmSWYsHqg
# 334 Bloor St W, Toronto, ON M5S 1W9, Canada
# ChIJW8gjQJY0K4gRJUcNBH9kzNY
# 399 Bathurst St, Toronto, ON M5T 2S8, Canada
# ChIJEYyn8eg0K4gRyN026fEyF3k
# 659 Queen St W, Toronto, ON M6G 1L1, Canada
# ChIJWQ3uLuc0K4gRrDFKYBPJ_xw
# 455 Spadina Ave., Toronto, ON M5S 1A1, Canada
# ChIJDYcgAME0K4gRRlgw8LXe5C0
# 175 Roncesvalles Ave, Toronto, ON M6R 2L3, Canada
# ChIJoxTCnso1K4gR9VDcjedOOfg
# 1251 Bloor St W, Toronto, ON M6H 1N6, Canada
# ChIJ2V9y9nU1K4gRC4NhS1InsYo
# 700 University Ave, Toronto, ON M5G 1Z5, Canada
# ChIJp1CiZ8g0K4gRiZqe7ALuJ8Y
# 1728 Bloor St W, Toronto, ON M6P 1A8, Canada
# ChIJD4pXIjA0K4gR7BJ_ZRPzz3M
# 610 University Ave, Toronto, ON M5J 1A7, Canada
# ChIJp1CiZ8g0K4gRsrmHWTwVc-s
# 1034 King St W, Toronto, ON M6K 3M9, Canada
# ChIJn3sm7AI1K4gRXoRjN9iu2zU
# 595 Bay St., Toronto, ON M5G 2C2, Canada
# ChIJv9gj3so0K4gRSecqWuO3ON4
# 480 University Ave, Toronto, ON M5G 1V2, Canada
# ChIJ8_AW44g1K4gRwTWengxrOTE
# 585 University Ave, Toronto, ON M5G 2N2, Canada
# ChIJEZAFX901K4gR4vISIVcevhk
# 444 Yonge St, Toronto, ON M5G 2B3, Canada
# ChIJVSOrrYE1K4gRX-Kp3S8_iKE
# 181 Bay St., Toronto, ON M5J 2T3, Canada
# ChIJuYMaPS3L1IkRZNmHv7VcKDI
# 200 King St E, Toronto, ON M5W 3A8, Canada
# ChIJ900Me5w0K4gRTRacM6GxIws
# 119 Spadina Ave., Toronto, ON M5V 2L1, Canada
# ChIJ-R_duds0K4gRtwrgpOFrKWs
# University Ave &, Dundas St W, Toronto, ON M5G, Canada
# ChIJR3hqPow1K4gRFEsKIgtIf_E
# 438 University Ave, Toronto, ON M5G 2K8, Canada
# ChIJp1CiZ8g0K4gReap38_wqKUo
# 170 University Ave, Toronto, ON M5H 3B3, Canada
# ChIJ_dCDHtI0K4gRePQIryFXb3Q
# 657 University Ave, Toronto, ON M5G 2C4, Canada
# ChIJp1CiZ8g0K4gReGPujQM6rJ8
# 70 Gerrard St W, Toronto, ON M5G 1J5, Canada
# ChIJRdo8D8o0K4gRn2jZdtejfK0
# 477 Dundas St W, Toronto, ON M5T 1H1, Canada
# ChIJg3WwfsQ0K4gR4rgms8A2ZeM
# 55 York St, Toronto, ON M5J 1R7, Canada
# ChIJcfAUD9M0K4gRaEg0EJkSGKo
# 56 Wellesley St W Unit 104, Toronto, ON M5S 2S3, Canada
# ChIJPaAzSLE0K4gRPzVWkITBTfY
# 663 Yonge St, Toronto, ON M4Y 1Z9, Canada
# ChIJU-xIALI0K4gR0eyZLILU1Xw
# 555 Yonge St, Toronto, ON M4Y 3A6, Canada
# ChIJ7YAIlrM0K4gR-kFykOR3hqw
# 175 Bloor St E, Toronto, ON M4W 3R8, Canada
# ChIJ3eveSVPL1IkRac5efNeMomw
# 1170 Bay St., Toronto, ON M5S 2B4, Canada
# ChIJHeYziq40K4gR_LCcUyF9JL0
# 419 Bloor St E, Toronto, ON M4W 1H7, Canada
# ChIJAQ_RhlPL1IkR6QyQAt1WSsc
# 246 Bloor St W, Toronto, ON M5S 1V4, Canada
# ChIJJYPgm7w0K4gRcHLkGIzlDUc
# 769 Yonge St, Toronto, ON M4W 2G4, Canada
# ChIJHeYziq40K4gREZu8pI-2WGw
# 2 Bloor St E, Toronto, ON M4W 1A8, Canada
# ChIJQYa4K6w0K4gRWex8DUl7bkQ
# 175 Dundas St E, Toronto, ON M5A 1Z4, Canada
# ChIJl2Zkh4_L1IkRA1NaHSee7Fc
# 26 Dundas St E, Toronto, ON M5B 2L6, Canada
# ChIJpzigsH3L1IkRFfne2wTd3VU
# 10 Dundas St E Suite 104, Toronto, ON M5B 2G8, Canada
# ChIJ8ex6zco0K4gRjLZu7rhWN9s
# 176 Front St E, Toronto, ON M5A 1E6, Canada
# ChIJB0WBZzrL1IkReal_H7OJdzI
# 77 Lower Jarvis St, Toronto, ON M5E 1N1, Canada
# ChIJ4WI43C_L1IkRa4UXlmNVXgs
# 241 Church St, Toronto, ON M5B 1Z4, Canada
# ChIJzQaiozXL1IkRpzcwykmW4pE
# 21 Harbour St, Toronto, ON M5J 2Y4, Canada
# ChIJv25bjpnL1IkRRJ9Z20fFyms
# The PATH - Maple Leaf Square, Toronto, ON M5J 2J3, Canada
# ChIJvSQrSNHL1IkRc5uGpQI0Bmc
# 51 Dockside Dr, Toronto, ON M5A 0B6, Canada
# ChIJOb2NOCTL1IkRw4H22JSrkZI
# 55 Front St E, Toronto, ON M5E 1B5, Canada
# ChIJN43LGy7L1IkRwhaHHBw1y0s
# 18 King St E Suite 105, Toronto, ON M5C 1C4, Canada
# ChIJcQGmZDLL1IkRUftlAxboh6Q
# 40 King St W, Toronto, ON M5H 3Y2, Canada
# ChIJn4_UWS3L1IkR-pF930hyqPo
# 581 Parliament St, Toronto, ON M4X 1P7, Canada
# ChIJoUteqlrL1IkRS7ODKh-jDzg
# 111 Carlton St, Toronto, ON M5B 2G3, Canada
# ChIJbeu4m0vL1IkRmNwVXwudskA
# 563 Sherbourne St, Toronto, ON M4X 1W7, Canada
# ChIJhScszVPL1IkRw0fuN585J5U
# 250 Bloor St E, Toronto, ON M4W 1E5, Canada
# ChIJ3eveSVPL1IkR3YyH6f40hys
# 1 Mt Pleasant Rd, Toronto, ON M4Y 2Y5, Canada
# ChIJ3eveSVPL1IkRrk5owb3Otg8
# 589 King St E, Toronto, ON M5V 1M1, Canada
# ChIJ_zidyGrL1IkRZEBiUYHrYZ0
# 323 Richmond St E, Toronto, ON M5A 4R3, Canada
# ChIJvfad4jnL1IkRt2xD1IWWFfA
# 547 Gerrard St E, Toronto, ON M4M 1X7, Canada
# ChIJ5XiPiWjL1IkRU4bz-rI-O2M
# 69 Regent Park Blvd, Toronto, ON M5A 0K7, Canada
# ChIJ4wIFDkHL1IkRI39sFZH5SZI
# 2 Queen St E, Toronto, ON M5C 3G7, Canada
# ChIJi7ufajPL1IkRViaV30FCwv8
# 14 St Matthews Rd, Toronto, ON M4M 2B5, Canada
# ChIJJR6N1GfL1IkR5CpkDkybTi8
# 65 Queen St W, Toronto, ON M5H 2M5, Canada
# ChIJhXg848w0K4gR3mpb_F6ZJsk
# 829 Lake Shore Blvd E, Toronto, ON M4M 1B2, Canada
# ChIJd1ayK3XL1IkRyz7Ef-Hod2U

# %%
import pandas as pd
import time
import json
import datetime
import pprint
from selenium import webdriver
from datetime import datetime
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains

# global str
# string= "Currently 27% busy, usually 33% busy."
import re
getPlaceIDURL='https://googlemaps.github.io/js-samples/dist/samples/places-placeid-finder/index.html'
###############################################
#loading URL_list
df = pd.read_csv ('TimhortonsURL.csv')
# print (df)
url_list= df["URL"].values
# print(url_list)
#####################################################################
#opernWebdriver
browser = webdriver.Firefox()
######################################################################
weekDay=["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]
# a Python object (dict):

########################################### prepare document to collect the data
document = {}
document["GoogleID"]="213424325432sdfdg"
document["currently-occupied-by"]= 112
document["name"]="Tim Hortons"
document["address"]="195 Westney Rd S, Ajax, ON L1S 2C9"

for i in weekDay:
    document[i]={}
#################################################
browser.get('https://www.google.ca/maps/place/Tim+Hortons/data=!4m5!3m4!1s0x89d51e6c109c7bb9:0xe862cf9d09617ef7!8m2!3d43.8861392!4d-78.945305?authuser=0&hl=en&rclk=1')
browser.execute_script("window.scrollTo(0, 20)") 
#############################################################
#get the addresss
data_item_id=browser.find_elements(By.XPATH,"//button[@data-item-id='address']")

for div in  data_item_id:
    if div.get_attribute('aria-label'):
#             print(div.get_attribute('aria-label'))
            string=div.get_attribute('aria-label')
#             print(string[string.find(": ")+2:])
            string= string[string.find(": ")+2:]+', Canada'
            document["address"]=string
            print(string)

#############################################################
div_tag =browser.find_elements(By.TAG_NAME , "div")
weekIndex=-1
lastTime="p.m"
for div in  div_tag:
    if div.get_attribute('aria-label'):
        divString=div.get_attribute('aria-label')
        if divString:
            ####################################
            if "a.m" in divString and "p.m" in lastTime:
                weekIndex=weekIndex+1 ##a new day    
            #################################### case of currently time         
            if "Currently" in divString:
                busy= re.findall(r'\d+',divString)[1]
                now = datetime.now()
                AMorPM=" a.m"
                current_time = now.strftime("%H")
                if int(current_time)>12:
                    current_time=int(current_time)%12
                    current_time=str(current_time)
                    AMorPM=" p.m"
                theTime=current_time+AMorPM
                document[weekDay[weekIndex]][theTime]=busy
                lastTime=theTime
            if "a.m" in divString or "p.m" in divString:
                busy=int(divString[0:divString.find("%")])
                if "a.m" in divString:
                    AMorPM = " a.m"
                else:
                    AMorPM = " p.m"
                timepm= re.findall(r'\d+',divString)[1]
                theTime= timepm+AMorPM
                document[weekDay[weekIndex]][theTime]=busy
                lastTime=theTime
pprint.pprint(document)

#############################################
#get PlaceID using the saved Address
browser.get(getPlaceIDURL)
input_text= browser.find_element(By.XPATH,"//input[@id='pac-input']")
print(input_text.get_attribute('placeholder'))
time.sleep(5)
input_text.click()
input_text.send_keys(document["address"])
time.sleep(2)
input_text.send_keys(Keys.ARROW_DOWN)
input_text.send_keys(Keys.ENTER)
time.sleep(2)

document["GoogleID"]=browser.find_element(By.XPATH, "//span[@id='place-id']").text
print(document["GoogleID"])
#############################################

df_data =pd.DataFrame([document])
df_data.to_csv('data.csv', mode='a', index=False, header=False)

# %%
import re
vv= "19% busy at 3 p.m.."
nn= int(re.findall(r'\d+',vv)[0])
print(nn)
print(type(nn))
# Out:
# 19
# <class 'int'>

# %%
string='2 Queen St E, Toronto, ON M5C 3G7b'
print(string[0:-1])
# Out:
# 2 Queen St E, Toronto, ON M5C 3G7

# %% [markdown]
# ### This notebook to get the PopularTimes and save it in csv file

# %%
import json
import datetime
import pprint
from selenium import webdriver
from datetime import datetime
from selenium.webdriver.common.by import By
import time
# global str
# string= "Currently 27% busy, usually 33% busy."
import re

browser = webdriver.Firefox()

weekDay=["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]
# a Python object (dict):
document = {}
document["GoogleID"]="213424325432sdfdg"
document["currently-occupied-by"]= 112
document["name"]="Tim Hortons"
document["address"]="195 Westney Rd S, Ajax, ON L1S 2C9"

for i in weekDay:
    document[i]={}
#################################################
# x[]
# print(document)
# convert into JSON:
# y = json.dumps(document)
# print(y)
# the result is a JSON string:
#################################################

# %%
browser.get('https://www.google.ca/maps/place/Tim+Hortons/data=!4m5!3m4!1s0x89d51e6c109c7bb9:0xe862cf9d09617ef7!8m2!3d43.8861392!4d-78.945305?authuser=0&hl=en&rclk=1')
# browser.find_element_by_xpath('//input[@node-type="searchInput"]')
browser.execute_script("window.scrollTo(0, 20)") 
# anchor_tag=browser.find_elements(By.CLASS_NAME , 'O9Q0Ff-NmME3c-Utye1-ZMv3u O9Q0Ff-NmME3c-Utye1-ZMv3u-SfQLQb-V67aGc')
time.sleep(4)
div_tag =browser.find_elements(By.TAG_NAME , "div")
# # print(anchor_tag)
weekIndex=-1
lastTime="p.m"
for div in  div_tag:
    if div.get_attribute('aria-label'):
        divString=div.get_attribute('aria-label')
        if divString:
            ####################################
            if "a.m" in divString and "p.m" in lastTime:
                weekIndex=weekIndex+1 ##a new day    
            #################################### case of currently time         
            if "Currently" in divString:
    #             print( re.findall(r'\d+',divString)[1])
                busy= re.findall(r'\d+',divString)[1]
                now = datetime.now()
                AMorPM=" a.m"
                current_time = now.strftime("%H")
                # current_time="6"
    #             print("Current Time =", current_time)
                if int(current_time)>12:
    #                 print(int(current_time)%12)
                    current_time=int(current_time)%12
                    current_time=str(current_time)
                    AMorPM=" p.m"
                theTime=current_time+AMorPM
                document[weekDay[weekIndex]][theTime]=busy
                lastTime=theTime
            if "a.m" in divString or "p.m" in divString:
                busy=int(divString[0:divString.find("%")])
#                 theTime=divString[divString.find("..")-5:divString.find("..")]
                if "a.m" in divString:
                    AMorPM = " a.m"
                else:
                    AMorPM = " p.m"
                time= re.findall(r'\d+',divString)[1]
                theTime= time+AMorPM
                document[weekDay[weekIndex]][theTime]=busy
                lastTime=theTime





pprint.pprint(document)
# Out:
# {'Friday': {'1 p.m': 59,
#             '10 a.m': 87,
#             '10 p.m': 1,
#             '11 a.m': 80,
#             '12 p.m': 69,
#             '2 p.m': 52,
#             '3 p.m': 47,
#             '4 a.m': 0,
#             '4 p.m': 42,
#             '5 a.m': 9,
#             '5 p.m': 36,
#             '6 a.m': 26,
#             '6 p.m': 28,
#             '7 a.m': 48,
#             '7 p.m': 20,
#             '8 a.m': 69,
#             '8 p.m': 12,
#             '9 a.m': 84,
#             '9 p.m': 6},
#  'GoogleID': '213424325432sdfdg',
#  'Monday': {'1 p.m': 50,
#             '10 a.m': 68,
#             '10 p.m': 1,
#             '11 a.m': 67,
#             '12 p.m': 60,
#             '2 p.m': 40,
#             '3 p.m': 34,
#             '4 a.m': 0,
#             '4 p.m': 31,
#             '5 a.m': 8,
#             '5 p.m': 30,
#             '6 a.m': 19,
#             '6 p.m': 27,
#             '7 a.m': 33,
#             '7 p.m': 22,
#             '8 a.m': 49,
#             '8 p.m': 15,
#             '9 a.m': 62,
#             '9 p.m': 8},
#  'Saturday': {'1 p.m': 54,
#               '10 a.m': 100,
#               '10 p.m': 20,
#               '11 a.m': 96,
#               '12 p.m': 76,
#               '2 p.m': 40,
#               '3 p.m': 35,
#               '4 a.m': 0,
#               '4 p.m': 34,
#               '5 a.m': 1,
#               '5 p.m': 34,
#               '6 a.m': 7,
#               '6 p.m': 33,
#               '7 a.m': 24,
#               '7 p.m': 30,
#               '8 a.m': 52,
#               '8 p.m': 27,
#               '9 a.m': 82,
#               '9 p.m': 24},
#  'Sunday': {'1 p.m': 68,
#             '10 a.m': 74,
#             '10 p.m': 9,
#             '11 a.m': 80,
#             '12 p.m': 78,
#             '2 p.m': 54,
#             '3 p.m': 39,
#             '4 a.m': 0,
#             '4 p.m': 27,
#             '5 a.m': 5,
#             '5 p.m': 20,
#             '6 a.m': 15,
#             '6 p.m': 18,
#             '7 a.m': 29,
#             '7 p.m': 18,
#             '8 a.m': 45,
#             '8 p.m': 17,
#             '9 a.m': 61,
#             '9 p.m': 14},
#  'Thursday': {'1 p.m': 62,
#               '10 a.m': 88,
#               '10 p.m': 5,
#               '11 a.m': 85,
#               '12 p.m': 75,
#               '2 p.m': 52,
#               '3 p.m': 44,
#               '4 a.m': 0,
#               '4 p.m': 40,
#               '5 a.m': 14,
#               '5 p.m': 37,
#               '6 a.m': 30,
#               '6 p.m': 32,
#               '7 a.m': 49,
#               '7 p.m': 26,
#               '8 a.m': 68,
#               '8 p.m': 19,
#               '9 a.m': 82,
#               '9 p.m': 12},
#  'Tuesday': {'1 p.m': 57,
#              '10 a.m': 64,
#              '10 p.m': 5,
#              '11 a.m': 66,
#              '12 p.m': 64,
#              '2 p.m': 47,
#              '3 p.m': '37',
#              '4 a.m': 0,
#              '4 p.m': 31,
#              '5 a.m': 11,
#              '5 p.m': 27,
#              '6 a.m': 26,
#              '6 p.m': 24,
#              '7 a.m': 42,
#              '7 p.m': 21,
#              '8 a.m': 54,
#              '8 p.m': 16,
#              '9 a.m': 61,
#              '9 p.m': 11},
#  'Wednesday': {'1 p.m': 51,
#                '10 a.m': 71,
#                '10 p.m': 9,
#                '11 a.m': 67,
#                '12 p.m': 59,
#                '2 p.m': 44,
#                '3 p.m': 40,
#                '4 a.m': 0,
#                '4 p.m': 37,
#                '5 a.m': 15,
#                '5 p.m': 35,
#                '6 a.m': 30,
#                '6 p.m': 32,
#                '7 a.m': 47,
#                '7 p.m': 27,
#                '8 a.m': 61,
#                '8 p.m': 21,
#                '9 a.m': 70,
#                '9 p.m': 15},
#  'address': '195 Westney Rd S, Ajax, ON L1S 2C9',
#  'currently-occupied-by': 112,
#  'name': 'Tim Hortons'}

# %%
# dict_ = {'key 1': 'value 1', 'key 2': 'value 2', 'key 3': 'value 3'}
import pandas as pd
df =pd.DataFrame([document])

# %%
print(df.head())
# Out:
#             GoogleID  currently-occupied-by         name  \
# 0  213424325432sdfdg                    112  Tim Hortons
#
#                               address  \
# 0  195 Westney Rd S, Ajax, ON L1S 2C9
#
#                                               Sunday  \
# 0  {'4 a.m': 0, '5 a.m': 5, '6 a.m': 15, '7 a.m':...
#
#                                               Monday  \
# 0  {'4 a.m': 0, '5 a.m': 8, '6 a.m': 19, '7 a.m':...
#
#                                              Tuesday  \
# 0  {'4 a.m': 0, '5 a.m': 11, '6 a.m': 26, '7 a.m'...
#
#                                            Wednesday  \
# 0  {'4 a.m': 0, '5 a.m': 15, '6 a.m': 30, '7 a.m'...
#
#                                             Thursday  \
# 0  {'4 a.m': 0, '5 a.m': 14, '6 a.m': 30, '7 a.m'...
#
#                                               Friday  \
# 0  {'4 a.m': 0, '5 a.m': 9, '6 a.m': 26, '7 a.m':...
#
#                                             Saturday
# 0  {'4 a.m': 0, '5 a.m': 1, '6 a.m': 7, '7 a.m': ...

# %%
with open('personal1.json', 'w') as json_file:
    json.dump(document, json_file)

# %%
print(df.iloc[0].values)
# Out:
# ['213424325432sdfdg' 112 'Tim Hortons'
#  '195 Westney Rd S, Ajax, ON L1S 2C9'
#  {'4 a.m': 0, '5 a.m': 5, '6 a.m': 15, '7 a.m': 29, '8 a.m': 45, '9 a.m': 61, '10 a.m': 74, '11 a.m': 80, '12 p.m': 78, '1 p.m': 68, '2 p.m': 54, '3 p.m': 39, '4 p.m': 27, '5 p.m': 20, '6 p.m': 18, '7 p.m': 18, '8 p.m': 17, '9 p.m': 14, '10 p.m': 9}
#  {'4 a.m': 0, '5 a.m': 8, '6 a.m': 19, '7 a.m': 33, '8 a.m': 49, '9 a.m': 62, '10 a.m': 68, '11 a.m': 67, '12 p.m': 60, '1 p.m': 50, '2 p.m': 40, '3 p.m': 34, '4 p.m': 31, '5 p.m': 30, '6 p.m': 27, '7 p.m': 22, '8 p.m': 15, '9 p.m': 8, '10 p.m': 1}
#  {'4 a.m': 0, '5 a.m': 11, '6 a.m': 26, '7 a.m': 42, '8 a.m': 54, '9 a.m': 61, '10 a.m': 64, '11 a.m': 66, '12 p.m': 64, '1 p.m': 57, '2 p.m': 47, '3 p.m': '37', '4 p.m': 31, '5 p.m': 27, '6 p.m': 24, '7 p.m': 21, '8 p.m': 16, '9 p.m': 11, '10 p.m': 5}
#  {'4 a.m': 0, '5 a.m': 15, '6 a.m': 30, '7 a.m': 47, '8 a.m': 61, '9 a.m': 70, '10 a.m': 71, '11 a.m': 67, '12 p.m': 59, '1 p.m': 51, '2 p.m': 44, '3 p.m': 40, '4 p.m': 37, '5 p.m': 35, '6 p.m': 32, '7 p.m': 27, '8 p.m': 21, '9 p.m': 15, '10 p.m': 9}
#  {'4 a.m': 0, '5 a.m': 14, '6 a.m': 30, '7 a.m': 49, '8 a.m': 68, '9 a.m': 82, '10 a.m': 88, '11 a.m': 85, '12 p.m': 75, '1 p.m': 62, '2 p.m': 52, '3 p.m': 44, '4 p.m': 40, '5 p.m': 37, '6 p.m': 32, '7 p.m': 26, '8 p.m': 19, '9 p.m': 12, '10 p.m': 5}
#  {'4 a.m': 0, '5 a.m': 9, '6 a.m': 26, '7 a.m': 48, '8 a.m': 69, '9 a.m': 84, '10 a.m': 87, '11 a.m': 80, '12 p.m': 69, '1 p.m': 59, '2 p.m': 52, '3 p.m': 47, '4 p.m': 42, '5 p.m': 36, '6 p.m': 28, '7 p.m': 20, '8 p.m': 12, '9 p.m': 6, '10 p.m': 1}
#  {'4 a.m': 0, '5 a.m': 1, '6 a.m': 7, '7 a.m': 24, '8 a.m': 52, '9 a.m': 82, '10 a.m': 100, '11 a.m': 96, '12 p.m': 76, '1 p.m': 54, '2 p.m': 40, '3 p.m': 35, '4 p.m': 34, '5 p.m': 34, '6 p.m': 33, '7 p.m': 30, '8 p.m': 27, '9 p.m': 24, '10 p.m': 20}]

# %%
df.to_csv('data.csv', mode='a', index=False, header=False)
